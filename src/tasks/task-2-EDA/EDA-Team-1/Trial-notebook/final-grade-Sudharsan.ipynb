# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.style.use("seaborn-whitegrid")
# Out:
# <ipython-input-1-ba24960c47bd>:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")

# %%
from google.colab import drive
drive.mount('/content/drive')

file_id = '1F-3LyHqiy0Rptz7A6yF1x1a-pccva63e'
link = f'https://drive.google.com/uc?id={file_id}'
df = pd.read_csv(link)
# Out:
# Mounted at /content/drive

# %%
df
# Out:
#       Unnamed: 0  index school sex  age address famsize Pstatus  Medu  Fedu  \
# 0              0      0     GP   F   18       U     GT3       A     4     4
# 1              1      1     GP   F   17       U     GT3       T     1     1
# 2              2      2     GP   F   15       U     LE3       T     1     1
# 3              3      3     GP   F   15       U     GT3       T     4     2
# 4              4      4     GP   F   16       U     GT3       T     3     3
# ...          ...    ...    ...  ..  ...     ...     ...     ...   ...   ...
# 1039        1039    644     MS   F   19       R     GT3       T     2     3
# 1040        1040    645     MS   F   18       U     LE3       T     3     1
# 1041        1041    646     MS   F   18       U     GT3       T     1     1
# 1042        1042    647     MS   M   17       U     LE3       T     3     1
# 1043        1043    648     MS   M   18       R     LE3       T     3     2
#
#       ... freetime goout Dalc Walc  health  absences  G1  G2  G3 Subject
# 0     ...        3     4    1    1       3         6   5   6   6       1
# 1     ...        3     3    1    1       3         4   5   5   6       1
# 2     ...        3     2    2    3       3        10   7   8  10       1
# 3     ...        2     2    1    1       5         2  15  14  15       1
# 4     ...        3     2    1    2       5         4   6  10  10       1
# ...   ...      ...   ...  ...  ...     ...       ...  ..  ..  ..     ...
# 1039  ...        4     2    1    2       5         4  10  11  10       0
# 1040  ...        3     4    1    1       1         4  15  15  16       0
# 1041  ...        1     1    1    1       5         6  11  12   9       0
# 1042  ...        4     5    3    4       2         6  10  10  10       0
# 1043  ...        4     1    3    4       5         4  10  11  11       0
#
# [1044 rows x 36 columns]

# %%
weight_g1 = 0.3
weight_g2 = 0.3
weight_g3 = 0.4

# %%
df["Final_G"] = (df['G1'] * weight_g1) + (df['G2'] * weight_g2) + (df['G3'] * weight_g3)
df["Final_G"] = df["Final_G"].round()

# %%
df
# Out:
#       Unnamed: 0  index school sex  age address famsize Pstatus  Medu  Fedu  \
# 0              0      0     GP   F   18       U     GT3       A     4     4
# 1              1      1     GP   F   17       U     GT3       T     1     1
# 2              2      2     GP   F   15       U     LE3       T     1     1
# 3              3      3     GP   F   15       U     GT3       T     4     2
# 4              4      4     GP   F   16       U     GT3       T     3     3
# ...          ...    ...    ...  ..  ...     ...     ...     ...   ...   ...
# 1039        1039    644     MS   F   19       R     GT3       T     2     3
# 1040        1040    645     MS   F   18       U     LE3       T     3     1
# 1041        1041    646     MS   F   18       U     GT3       T     1     1
# 1042        1042    647     MS   M   17       U     LE3       T     3     1
# 1043        1043    648     MS   M   18       R     LE3       T     3     2
#
#       ... goout Dalc Walc health  absences  G1  G2  G3 Subject Final_G
# 0     ...     4    1    1      3         6   5   6   6       1     6.0
# 1     ...     3    1    1      3         4   5   5   6       1     5.0
# 2     ...     2    2    3      3        10   7   8  10       1     8.0
# 3     ...     2    1    1      5         2  15  14  15       1    15.0
# 4     ...     2    1    2      5         4   6  10  10       1     9.0
# ...   ...   ...  ...  ...    ...       ...  ..  ..  ..     ...     ...
# 1039  ...     2    1    2      5         4  10  11  10       0    10.0
# 1040  ...     4    1    1      1         4  15  15  16       0    15.0
# 1041  ...     1    1    1      5         6  11  12   9       0    10.0
# 1042  ...     5    3    4      2         6  10  10  10       0    10.0
# 1043  ...     1    3    4      5         4  10  11  11       0    11.0
#
# [1044 rows x 37 columns]

# %%
df = df.drop(['G1','G2','G3'], axis = 1)

# %%
df
# Out:
#       Unnamed: 0  index school sex  age address famsize Pstatus  Medu  Fedu  \
# 0              0      0     GP   F   18       U     GT3       A     4     4
# 1              1      1     GP   F   17       U     GT3       T     1     1
# 2              2      2     GP   F   15       U     LE3       T     1     1
# 3              3      3     GP   F   15       U     GT3       T     4     2
# 4              4      4     GP   F   16       U     GT3       T     3     3
# ...          ...    ...    ...  ..  ...     ...     ...     ...   ...   ...
# 1039        1039    644     MS   F   19       R     GT3       T     2     3
# 1040        1040    645     MS   F   18       U     LE3       T     3     1
# 1041        1041    646     MS   F   18       U     GT3       T     1     1
# 1042        1042    647     MS   M   17       U     LE3       T     3     1
# 1043        1043    648     MS   M   18       R     LE3       T     3     2
#
#       ... romantic famrel freetime goout  Dalc  Walc  health absences Subject  \
# 0     ...       no      4        3     4     1     1       3        6       1
# 1     ...       no      5        3     3     1     1       3        4       1
# 2     ...       no      4        3     2     2     3       3       10       1
# 3     ...      yes      3        2     2     1     1       5        2       1
# 4     ...       no      4        3     2     1     2       5        4       1
# ...   ...      ...    ...      ...   ...   ...   ...     ...      ...     ...
# 1039  ...       no      5        4     2     1     2       5        4       0
# 1040  ...       no      4        3     4     1     1       1        4       0
# 1041  ...       no      1        1     1     1     1       5        6       0
# 1042  ...       no      2        4     5     3     4       2        6       0
# 1043  ...       no      4        4     1     3     4       5        4       0
#
#      Final_G
# 0        6.0
# 1        5.0
# 2        8.0
# 3       15.0
# 4        9.0
# ...      ...
# 1039    10.0
# 1040    15.0
# 1041    10.0
# 1042    10.0
# 1043    11.0
#
# [1044 rows x 34 columns]

# %%
df.to_csv('result.csv', index=False)

# %%
ses_df = pd.DataFrame(df[['sex', 'address', 'famsize' , 'Pstatus','Medu','Fedu','Mjob','Fjob',
                    'guardian','famsup','schoolsup', 'internet','paid','higher','Final_G']])

# %%
ses_df
# Out:
#      sex address famsize Pstatus  Medu  Fedu      Mjob      Fjob guardian  \
# 0      F       U     GT3       A     4     4   at_home   teacher   mother
# 1      F       U     GT3       T     1     1   at_home     other   father
# 2      F       U     LE3       T     1     1   at_home     other   mother
# 3      F       U     GT3       T     4     2    health  services   mother
# 4      F       U     GT3       T     3     3     other     other   father
# ...   ..     ...     ...     ...   ...   ...       ...       ...      ...
# 1039   F       R     GT3       T     2     3  services     other   mother
# 1040   F       U     LE3       T     3     1   teacher  services   mother
# 1041   F       U     GT3       T     1     1     other     other   mother
# 1042   M       U     LE3       T     3     1  services  services   mother
# 1043   M       R     LE3       T     3     2  services     other   mother
#
#      famsup schoolsup internet paid higher  Final_G
# 0        no       yes       no   no    yes      6.0
# 1       yes        no      yes   no    yes      5.0
# 2        no       yes      yes  yes    yes      8.0
# 3       yes        no      yes  yes    yes     15.0
# 4       yes        no       no  yes    yes      9.0
# ...     ...       ...      ...  ...    ...      ...
# 1039     no        no      yes   no    yes     10.0
# 1040    yes        no      yes   no    yes     15.0
# 1041     no        no       no   no    yes     10.0
# 1042     no        no      yes   no    yes     10.0
# 1043     no        no      yes   no    yes     11.0
#
# [1044 rows x 15 columns]

# %%
ses_df.columns
# Out:
# Index(['sex', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob',
#        'guardian', 'famsup', 'schoolsup', 'internet', 'paid', 'higher',
#        'Final_G'],
#       dtype='object')

# %%
X = ses_df.copy()
y = X.pop("Final_G")

# Label encoding for categoricals
for colname in X.select_dtypes("object"):
    X[colname], _ = X[colname].factorize()

# All discrete features should now have integer dtypes
discrete_features = X.dtypes == int

# %%
# A look at a few features with their MI scores
from sklearn.feature_selection import mutual_info_regression

def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(X, y, discrete_features)
mi_scores[::]
# Out:
# higher       0.054385
# Fedu         0.045500
# schoolsup    0.036866
# paid         0.033634
# internet     0.025487
# Medu         0.020862
# Mjob         0.015538
# famsup       0.011307
# guardian     0.006223
# famsize      0.004452
# Pstatus      0.002171
# address      0.002138
# sex          0.000000
# Fjob         0.000000
# Name: MI Scores, dtype: float64

# %%
# Bar chat for a somewhat easier comparision
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores")


plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores)
